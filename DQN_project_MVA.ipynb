# %% [markdown]
# **You may need to install [OpenCV](https://pypi.python.org/pypi/opencv-python) and [scikit-video](http://www.scikit-video.org/stable/).**

# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import json
import skvideo.io
import cv2

from keras.models import Sequential,model_from_json
from keras.layers.core import Dense,Dropout
from keras.optimizers import sgd
from keras.layers import Conv2D, MaxPooling2D, Activation, AveragePooling2D,Reshape,BatchNormalization,Flatten

# %% [markdown]
# # MiniProject #3: Deep Reinforcement Learning

# %% [markdown]
# __Notations__: $E_p$ is the expectation under probability $p$. Please justify each of your answer and widely comment your code.

# %% [markdown]
# # Context

# %% [markdown]
# In a reinforcement learning algorithm, we modelize each step $t$ as an action $a_t$ obtained from a state $s_t$, i.e. $\{(a_{t},s_{t})_{t\leq T}\}$ having the Markov property. We consider a discount factor $\gamma \in [0,1]$ that ensures convergence. The goal is to find among all the policies $\pi$, one that maximizes the expected reward:
#
# \begin{equation*}
# R(\pi)=\sum_{t\leq T}E_{p^{\pi}}[\gamma^t r(s_{t},a_{t})] \> ,
# \end{equation*}
#
# where:
# \begin{equation*}p^{\pi}(a_{0},a_{1},s_{1},...,a_{T},s_{T})=p(a_{0})\prod_{t=1}^{T}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# We note the $Q$-function:
#
# \begin{equation*}Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] \> .
# \end{equation*}
#
# Thus, the optimal Q function is:
# \begin{equation*}
# Q^*(s,a)=\max_{\pi}Q^\pi(s,a) \> .
# \end{equation*}
#
# In this project, we will apply the deep reinforcement learning techniques to a simple game: an agent will have to learn from scratch a policy that will permit it maximizing a reward.

# %% [markdown]
# ## The environment, the agent and the game

# %% [markdown]
# ### The environment

# %% [markdown]
# ```Environment``` is an abstract class that represents the states, rewards, and actions to obtain the new state.

# %%
class Environment(object):
    def __init__(self):
        pass

    def act(self, act):
        """
        One can act on the environment and obtain its reaction:
        - the new state
        - the reward of the new state
        - should we continue the game?

        :return: state, reward, game_over
        """
        
        pass


    def reset(self):
        """
        Reinitialize the environment to a random state and returns
        the original state

        :return: state
        """
        pass
    
    def draw(self):
        """
        Visualize in the console or graphically the current state
        """
        pass

# %% [markdown]
# The method ```act``` allows to act on the environment at a given state $s_t$ (stored internally), via action $a_t$. The method will return the new state $s_{t+1}$, the reward $r(s_{t},a_{t})$ and determines if $t\leq T$ (*game_over*).
#
# The method ```reset``` simply reinitializes the environment to a random state $s_0$.
#
# The method ```draw``` displays the current state $s_t$ (this is useful to check the behavior of the Agent).
#
# We modelize $s_t$ as a tensor, while $a_t$ is an integer.

# %% [markdown]
# ### The Agent

# %% [markdown]
# The goal of the ```Agent``` is to interact with the ```Environment``` by proposing actions $a_t$ obtained from a given state $s_t$ to attempt to maximize its __reward__ $r(s_t,a_t)$. We propose the following abstract class:

# %%
class Agent(object):
    def __init__(self, epsilon=0.1, n_action=4):
        self.epsilon = epsilon
        self.n_action = n_action
    
    def set_epsilon(self,e):
        self.epsilon = e

    def act(self,s,train=True):
        """ This function should return the next action to do:
        an integer between 0 and 4 (not included) with a random exploration of epsilon"""
        if train:
            if np.random.rand() <= self.epsilon:
                a = np.random.randint(0, self.n_action, size=1)[0]
            else:
                a = self.learned_act(s)
        else: # in some cases, this can improve the performance.. remove it if poor performances
            a = self.learned_act(s)

        return a

    def learned_act(self,s):
        """ Act via the policy of the agent, from a given state s
        it proposes an action a"""
        pass

    def reinforce(self, s, n_s, a, r, game_over_):
        """ This function is the core of the learning algorithm. 
        It takes as an input the current state s_, the next state n_s_
        the action a_ used to move from s_ to n_s_ and the reward r_.
        
        Its goal is to learn a policy.
        """
        pass

    def save(self):
        """ This function returns basic stats if applicable: the
        loss and/or the model"""
        pass

    def load(self):
        """ This function allows to restore a model"""
        pass

# %% [markdown]
# ***
# __Question 1__:
# Explain the function act. Why is ```epsilon``` essential?

# %% [markdown]
# The function $\textit{act}$ retuns the action to take for $\textit{train}$ or $\textit{test}$ process. If $\textit{train=True}$, agent takes a random action to explore environment if the initiation is smaller than the threshold epsilon; otherwise, it takes the actions based on state s given by a defined policy. The randomness is used because the agent don't have knowledge on the environment. In $\textit{train}$ process, the threshold seperates $\textit{exploration and exploitation}$ in a random manner.
#
# Espilon is important because it decide the frequency that an agent will explore environment.If epsilon is too small, the agent don't explore enough to learn the environment.The probability of taking a random action in the $\textit{train}$ is epsilon.
#
# A good strategy is to choose a high value of epsilon, close to 1, in the beginning because we don't know anything about values in the table. We can reduce it progressively as the agent becomes more confident at estimating Q-values.

# %% [markdown]
# ***
# ### The Game

# %% [markdown]
# The ```Agent``` and the ```Environment``` work in an interlaced way as in the following (take some time to understand this code as it is the core of the project)
#
# ```python
#
# epoch = 300
# env = Environment()
# agent = Agent()
#
#
# # Number of won games
# score = 0
# loss = 0
#
#
# for e in range(epoch):
#     # At each epoch, we restart to a fresh game and get the initial state
#     state = env.reset()
#     # This assumes that the games will end
#     game_over = False
#
#     win = 0
#     lose = 0
#
#     while not game_over:
#         # The agent performs an action
#         action = agent.act(state)
#
#         # Apply an action to the environment, get the next state, the reward
#         # and if the games end
#         prev_state = state
#         state, reward, game_over = env.act(action)
#
#         # Update the counters
#         if reward > 0:
#             win = win + reward
#         if reward < 0:
#             lose = lose -reward
#
#         # Apply the reinforcement strategy
#         loss = agent.reinforce(prev_state, state,  action, reward, game_over)
#
#     # Save as a mp4
#     if e % 10 == 0:
#         env.draw(e)
#
#     # Update stats
#     score += win-lose
#
#     print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
#           .format(e, epoch, loss, win, lose, win-lose))
#     agent.save()
# ```

# %% [markdown]
# # The game, *eat cheese*

# %% [markdown]
# A rat runs on an island and tries to eat as much as possible. The island is subdivided into $N\times N$ cells, in which there are cheese (+0.5) and poisonous cells (-1). The rat has a visibility of 2 cells (thus it can see $5^2$ cells). The rat is given a time $T$ to accumulate as much food as possible. It can perform 4 actions: going up, down, left, right.
#
# The goal is to code an agent to solve this task that will learn by trial and error. We propose the following environment:

# %%
class Environment(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %% [markdown]
# The following elements are important because they correspond to the hyper parameters for this project:

# %%
# parameters
size = 13
T=200
temperature=0.3
epochs_train= 200 # set small when debugging
epochs_test=200 # set small when debugging

# display videos
def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))

# %% [markdown]
# __Question 2__ Explain the use of the arrays ```position``` and ```board```.

# %% [markdown]
# $\textit{position}$ array is used to mark the current state of the agent. It is initialized with -1 the first,last two rows and the first two columns. These can be considered as $\textbf{walls}$. If the agent is on the position (x,y), the cell will be marked 1.
#
# The broad is used to give corresponding reward for the taken action. It's generated with random positions of cheese and poisson using binomial distribution.

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ***
# __Question 3__ Implement a random Agent (only ```learned_act``` needs to be implemented):

# %%
class RandomAgent(Agent):
    def __init__(self):
        super(RandomAgent, self).__init__()

    def learned_act(self,s):
        return np.random.randint(4)
#     def learned_act(self, s):
#         return np.random.randint(4)

# %% [markdown]
# ***
# ***
# __Question 4__ Visualize the game moves. You need to fill in the following function for the evaluation:

# %%
def test(agent,env,epochs,prefix=''):
    # Number of won games
    score = 0
        
    for e in range(epochs):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()

        win =0
        lose=0
        game_over = False
        
        while not game_over:
            action = agent.act(state)
            state, reward, game_over = env.act(action)
            if reward > 0:
                win = win + reward
            elif reward < 0:
                lose = lose - reward

        # Save as a mp4
        env.draw(prefix+str(e))

        # Update stats
        score = score + win-lose

        print("Win/lose count {}/{}. Average score ({})".format(win, lose, score/(1+e)))

    print('Final score: '+str(score/epochs))

# %%
# Initialize the game
env = Environment(grid_size=size, max_time=T,temperature=temperature)

# Initialize the agent!
agent = RandomAgent()

test(agent,env,epochs_test,prefix='random')
HTML(display_videos('random0.mp4'))
# Out:
# Win/lose count 7.5/7.0. Average score (0.5)
# Win/lose count 7.0/13.0. Average score (-2.75)
# Win/lose count 12.0/15.0. Average score (-2.8333333333333335)
# Win/lose count 8.5/12.0. Average score (-3.0)
# Win/lose count 10.0/11.0. Average score (-2.6)
# Win/lose count 10.5/10.0. Average score (-2.0833333333333335)
# Win/lose count 9.5/12.0. Average score (-2.142857142857143)
# Win/lose count 11.5/20.0. Average score (-2.9375)
# Win/lose count 12.5/8.0. Average score (-2.111111111111111)
# Win/lose count 9.0/14.0. Average score (-2.4)
# Win/lose count 12.5/11.0. Average score (-2.0454545454545454)
# Win/lose count 4.5/14.0. Average score (-2.6666666666666665)
# Win/lose count 10.5/20.0. Average score (-3.1923076923076925)
# Win/lose count 10.0/14.0. Average score (-3.25)
# Win/lose count 8.5/15.0. Average score (-3.466666666666667)
# Win/lose count 9.0/19.0. Average score (-3.875)
# Win/lose count 11.0/11.0. Average score (-3.6470588235294117)
# Win/lose count 10.0/12.0. Average score (-3.5555555555555554)
# Win/lose count 10.0/17.0. Average score (-3.736842105263158)
# Win/lose count 7.5/19.0. Average score (-4.125)
# Win/lose count 11.5/14.0. Average score (-4.0476190476190474)
# Win/lose count 11.5/17.0. Average score (-4.113636363636363)
# Win/lose count 17.5/17.0. Average score (-3.9130434782608696)
# Win/lose count 15.5/19.0. Average score (-3.8958333333333335)
# Win/lose count 7.0/12.0. Average score (-3.94)
# Win/lose count 6.0/12.0. Average score (-4.019230769230769)
# Win/lose count 9.5/18.0. Average score (-4.185185185185185)
# Win/lose count 8.0/15.0. Average score (-4.285714285714286)
# Win/lose count 11.5/26.0. Average score (-3.814917127071823)
# Win/lose count 15.0/20.0. Average score (-3.8214285714285716)
# Win/lose count 10.0/13.0. Average score (-3.8169398907103824)
# Win/lose count 1.5/12.0. Average score (-3.8532608695652173)
# Win/lose count 8.0/11.0. Average score (-3.848648648648649)
# Win/lose count 11.5/17.0. Average score (-3.85752688172043)
# Win/lose count 9.0/15.0. Average score (-3.8689839572192515)
# Win/lose count 15.5/18.0. Average score (-3.8617021276595747)
# Win/lose count 6.5/16.0. Average score (-3.8915343915343916)
# Win/lose count 10.5/16.0. Average score (-3.9)
# Win/lose count 8.0/14.0. Average score (-3.910994764397906)
# Win/lose count 14.5/15.0. Average score (-3.8932291666666665)
# Win/lose count 11.5/17.0. Average score (-3.901554404145078)
# Win/lose count 10.0/10.0. Average score (-3.881443298969072)
# Win/lose count 6.5/13.0. Average score (-3.894871794871795)
# Win/lose count 9.0/10.0. Average score (-3.8801020408163267)
# Win/lose count 14.0/16.0. Average score (-3.8705583756345177)
# Win/lose count 11.5/23.0. Average score (-3.909090909090909)
# Win/lose count 13.0/18.0. Average score (-3.9145728643216082)
# Win/lose count 8.5/19.0. Average score (-3.9475)
# Final score: -3.9475
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ## DQN

# %% [markdown]
# Let us assume here that $T=\infty$.
#
# ***
# __Question 5__ Let $\pi$ be a policy, show that:
#
# \begin{equation*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:
#
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
# Finally, deduce that a plausible objective is:
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# Let $\gamma$ be the discount factor that makes future rewards worthing less than immediate rewards. It enforces short-terms preference in the target.
#
# 1) for policy $\pi$, the state-value function Q is defined as:
# \begin{equation*}
# Q^{\pi}(s,a)=E_{\pi}[\sum_{n \geq 0} \gamma^n R_n| S_0=s',A_0=a']
#             = E_{\pi}[r_{t+1}( s',a')+\gamma r_{t+2}( s',a')+...+\gamma^nr_{t+n-1}( s',a')| s',a']
# \end{equation*}
#
# s is the state after s'. It implies that:
# \begin{equation*}
# Q^{\pi}(s,a)= E_{\pi}[r( s',a')+\gamma \underbrace{[r_{t+1}( s',a')+...]}_\text{$Q^{\pi}(s',a')$}| s',a']\\
# 	\Rightarrow \\
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')]
# \end{equation*}
#
#
#
# Q.E.D.
#
# 2) Let's show the optimal function Q^*(s,a) with Lemma Greedy Policy. A policy $\pi$' is said to act greedy with respect to $\pi$ if
# \begin{equation*}
# \pi '= argmax_{a \in A}q_{\pi}(s,a)
# \end{equation*}
# $$
# Lemma = \left\{
#     \begin{array}{l}
#         v_{\pi} \leq v_{\pi'}\\
#         v_{\pi'}(s)=v_{\pi}(s) \iff v_{\pi}(s)=v^*(s)
#     \end{array}
# \right.
# $$
#
# It implies that:
# \begin{equation*}
# Q^{*}(s,a)=r(s,a)+ \gamma \sum_{s'}p(s'|s,a)v^*(s') \\
# with v^*(s')=sup_{a \in A} Q^*(s,a)\\
# \Rightarrow \\
# Q^{*}(s,a)=r(s,a)+ \gamma \underbrace{ \sum_{s'} sup_{a \in A}p(s'|s,a)q^*(s,a) }_\text{$max_{a'}Q^*(s',a')$}\\
# \Rightarrow \\
# Q^{*}(s,a)=r(s,a)+ \gamma max_{a'}Q^*(s',a')
# \end{equation*}
#
#
# Q.E.D.
#
# 3) Let's define the objective function by mean-squared error in Q-values.We represent value function by deep Q-netword with weightes $\theta$.
# \begin{equation*}
# \mathcal{L}(\theta)=E[(\underbrace{r(s,a)+ \gamma max_{a'}Q^*(s',a',\theta)}_\text{target} - Q(s,a,\theta))^2]\\
# \Rightarrow\\
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}
# \end{equation*}
# Q.E.D.

# %% [markdown]
# ***
# The DQN-learning algorithm relies on these derivations to train the parameters $\theta$ of a Deep Neural Network:
#
# 1. At the state $s_t$, select the action $a_t$ with best reward using $Q_t$ and store the results;
#
# 2. Obtain the new state $s_{t+1}$ from the environment $p$;
#
# 3. Store $(s_t,a_t,s_{t+1})$;
#
# 4. Obtain $Q_{t+1}$ by minimizing  $\mathcal{L}$ from a recovered batch from the previously stored results.
#
# ***
# __Question 6__ Implement the class ```Memory``` that stores moves (in a replay buffer) via ```remember``` and provides a ```random_access``` to these. Specify a maximum memory size to avoid side effects. You can for example use a ```list()``` and set by default ```max_memory=100```.

# %%
class Memory(object):
    def __init__(self, max_memory=100):
        self.max_memory = max_memory
        self.memory = list()
        # self.discount = discount
        # self.model = model
        # self.num_actions = model.output_shape[-1]

    def remember(self, m):
        self.memory.append(m)
        if len(self.memory) > self.max_memory:
            del self.memory[0]
        return self.memory

    def random_access(self):
        #display(len(self.memory))
        num = np.random.randint(len(self.memory))
        return self.memory[num]

# %% [markdown]
# ***
# The pipeline we will use for training is given below:

# %%
def train(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %% [markdown]
# ***
# __Question 7__ Implement the DQN training algorithm using a cascade of fully connected layers. You can use different learning rate, batch size or memory size parameters. In particular, the loss might oscillate while the player will start to win the games. You have to find a good criterium.

# %%
class DQN(Agent):
    def __init__(self, grid_size,  epsilon = 0.1, memory_size=100, batch_size = 16,n_state=2):
        super(DQN, self).__init__(epsilon = epsilon)

        # Discount for Q learning
        self.discount = 0.99
        
        self.grid_size = grid_size
        
        # number of state
        self.n_state = n_state

        # Memory
        self.memory = Memory(memory_size)
        
        # Batch size when learning
        self.batch_size = batch_size

    def learned_act(self, s):
        move_ = self.model.predict(s[np.newaxis,:])
        return np.argmax(move_)

    def reinforce(self, s_, n_s_, a_, r_, game_over_):
        # Two steps: first memorize the states, second learn from the pool
        # https://www.samyzaf.com/ML/rl/qmaze.html
        self.memory.remember([s_, n_s_, a_, r_, game_over_])
        
        input_states = np.zeros((self.batch_size, 5,5,self.n_state))
        target_q = np.zeros((self.batch_size, 4))
        
        for i in range(self.batch_size):
            ######## FILL IN
            s_, n_s_, a_, r_, game_over_ = self.memory.random_access()
            #target_q[i] = #la fct Q, mais il manque des parametres
            
            if game_over_:
                target_reward = r_
                ######## FILL IN
            else:
                ######## FILL IN
                target_reward = r_ + self.discount * np.max(self.model.predict(n_s_[np.newaxis,:]))
                # https://becominghuman.ai/lets-build-an-atari-ai-part-1-dqn-df57e8ff3b26
                #https://towardsdatascience.com/convolutional-neural-networks-from-the-ground-up-c67bb41454e1
            input_states[i] = s_    
            target_q[i] = self.model.predict(s_[np.newaxis,:]) 
            target_q[i][a_] = target_reward
        ######## FILL IN
        # HINT: Clip the target to avoid exploiding gradients.. -- clipping is a bit tighter
        target_q = np.clip(target_q, -3, 3)

        l = self.model.train_on_batch(input_states, target_q)


        return l

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        model.compile("sgd", "mse")
        self.model = model

            
class DQN_FC(DQN):
    def __init__(self, *args, lr=0.1,**kwargs):
        super(DQN_FC, self).__init__( *args,**kwargs)
        
        # NN Model
        
        ####### FILL IN
        model = Sequential()
        model.add(Reshape((5*5*self.n_state,), input_shape=(5,5,self.n_state)))
        model.add(Dense(32, input_dim=5*5*self.n_state, activation='relu'))
        model.add(Dropout(0.5))
        model.add(Dense(16, activation='relu'))
        model.add(Dropout(0.5))
        model.add(Dense(4, activation='linear')
                  
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model
        model.summary()

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent, env, epochs_train, prefix='fc_train')
HTML(display_videos('fc_train10.mp4'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_8 (Reshape)          (None, 50)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 24)                1224
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_30 (Dense)             (None, 24)                600
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_31 (Dense)             (None, 4)                 100
# =================================================================
# Total params: 1,924
# Trainable params: 1,924
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/200 | Loss 0.0107 | Win/lose count 4.5/6.0 (-1.5)
# Epoch 001/200 | Loss 0.0184 | Win/lose count 2.5/6.0 (-3.5)
# Epoch 002/200 | Loss 0.0085 | Win/lose count 4.0/3.0 (1.0)
# Epoch 003/200 | Loss 0.0079 | Win/lose count 2.0/2.0 (0.0)
# Epoch 004/200 | Loss 0.0099 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 005/200 | Loss 0.0027 | Win/lose count 2.0/2.0 (0.0)
# Epoch 006/200 | Loss 0.0020 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 007/200 | Loss 0.0044 | Win/lose count 2.0/0 (2.0)
# Epoch 008/200 | Loss 0.0156 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 009/200 | Loss 0.0039 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 010/200 | Loss 0.0079 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 011/200 | Loss 0.0139 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 012/200 | Loss 0.0000 | Win/lose count 4.0/5.0 (-1.0)
# Epoch 013/200 | Loss 0.0071 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 014/200 | Loss 0.0001 | Win/lose count 2.0/2.0 (0.0)
# Epoch 015/200 | Loss 0.0000 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 016/200 | Loss 0.0078 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 017/200 | Loss 0.0120 | Win/lose count 6.5/7.0 (-0.5)
# Epoch 018/200 | Loss 0.0021 | Win/lose count 3.5/7.0 (-3.5)
# Epoch 019/200 | Loss 0.0021 | Win/lose count 1.5/6.0 (-4.5)
# Epoch 020/200 | Loss 0.0159 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 021/200 | Loss 0.0000 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 022/200 | Loss 0.0000 | Win/lose count 2.0/7.0 (-5.0)
# Epoch 023/200 | Loss 0.0127 | Win/lose count 3.0/3.0 (0.0)
# Epoch 024/200 | Loss 0.0159 | Win/lose count 3.5/1.0 (2.5)
# Epoch 025/200 | Loss 0.0079 | Win/lose count 2.0/0 (2.0)
# Epoch 026/200 | Loss 0.0060 | Win/lose count 5.5/4.0 (1.5)
# Epoch 027/200 | Loss 0.0154 | Win/lose count 3.0/3.0 (0.0)
# Epoch 028/200 | Loss 0.0026 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 029/200 | Loss 0.0020 | Win/lose count 3.0/1.0 (2.0)
# Epoch 030/200 | Loss 0.0081 | Win/lose count 6.0/6.0 (0.0)
# Epoch 031/200 | Loss 0.0023 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 032/200 | Loss 0.0003 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 033/200 | Loss 0.0078 | Win/lose count 3.5/6.0 (-2.5)
# Epoch 034/200 | Loss 0.0141 | Win/lose count 2.0/8.0 (-6.0)
# Epoch 035/200 | Loss 0.0118 | Win/lose count 3.0/7.0 (-4.0)
# Epoch 036/200 | Loss 0.0040 | Win/lose count 4.5/4.0 (0.5)
# Epoch 037/200 | Loss 0.0263 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 038/200 | Loss 0.0112 | Win/lose count 5.0/7.0 (-2.0)
# Epoch 039/200 | Loss 0.0096 | Win/lose count 3.0/6.0 (-3.0)
# Epoch 040/200 | Loss 0.0000 | Win/lose count 3.0/3.0 (0.0)
# Epoch 041/200 | Loss 0.0169 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 042/200 | Loss 0.0193 | Win/lose count 5.5/5.0 (0.5)
# Epoch 043/200 | Loss 0.0058 | Win/lose count 1.5/1.0 (0.5)
# Epoch 044/200 | Loss 0.0039 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 045/200 | Loss 0.0002 | Win/lose count 2.0/1.0 (1.0)
# Epoch 046/200 | Loss 0.0045 | Win/lose count 1.5/1.0 (0.5)
# Epoch 047/200 | Loss 0.0001 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 048/200 | Loss 0.0000 | Win/lose count 2.5/2.0 (0.5)
# Epoch 049/200 | Loss 0.0099 | Win/lose count 2.5/1.0 (1.5)
# Epoch 050/200 | Loss 0.0078 | Win/lose count 2.5/7.0 (-4.5)
# Epoch 051/200 | Loss 0.0000 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 052/200 | Loss 0.0020 | Win/lose count 4.5/3.0 (1.5)
# Epoch 053/200 | Loss 0.0020 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 054/200 | Loss 0.0020 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 055/200 | Loss 0.0001 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 056/200 | Loss 0.0001 | Win/lose count 2.0/1.0 (1.0)
# Epoch 057/200 | Loss 0.0001 | Win/lose count 2.0/5.0 (-3.0)
# Epoch 058/200 | Loss 0.0077 | Win/lose count 3.0/3.0 (0.0)
# Epoch 059/200 | Loss 0.0000 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 060/200 | Loss 0.0000 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 061/200 | Loss 0.0019 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 062/200 | Loss 0.0020 | Win/lose count 4.5/4.0 (0.5)
# Epoch 063/200 | Loss 0.0040 | Win/lose count 8.0/11.0 (-3.0)
# Epoch 064/200 | Loss 0.0020 | Win/lose count 4.5/2.0 (2.5)
# Epoch 065/200 | Loss 0.0001 | Win/lose count 5.0/3.0 (2.0)
# Epoch 066/200 | Loss 0.0043 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 067/200 | Loss 0.0000 | Win/lose count 2.5/6.0 (-3.5)
# Epoch 068/200 | Loss 0.0093 | Win/lose count 1.0/4.0 (-3.0)
# Epoch 069/200 | Loss 0.0079 | Win/lose count 1.5/7.0 (-5.5)
# Epoch 070/200 | Loss 0.0021 | Win/lose count 5.5/7.0 (-1.5)
# Epoch 071/200 | Loss 0.0078 | Win/lose count 2.5/0 (2.5)
# Epoch 072/200 | Loss 0.0000 | Win/lose count 2.5/2.0 (0.5)
# Epoch 073/200 | Loss 0.0049 | Win/lose count 1.5/4.0 (-2.5)
# Epoch 074/200 | Loss 0.0078 | Win/lose count 1.5/0 (1.5)
# Epoch 075/200 | Loss 0.0019 | Win/lose count 2.5/7.0 (-4.5)
# Epoch 076/200 | Loss 0.0021 | Win/lose count 3.0/1.0 (2.0)
# Epoch 077/200 | Loss 0.0000 | Win/lose count 2.0/2.0 (0.0)
# Epoch 078/200 | Loss 0.0000 | Win/lose count 3.5/2.0 (1.5)
# Epoch 079/200 | Loss 0.0039 | Win/lose count 5.0/10.0 (-5.0)
# Epoch 080/200 | Loss 0.0001 | Win/lose count 6.5/11.0 (-4.5)
# Epoch 081/200 | Loss 0.0021 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 082/200 | Loss 0.0080 | Win/lose count 3.0/2.0 (1.0)
# Epoch 083/200 | Loss 0.0078 | Win/lose count 5.5/3.0 (2.5)
# Epoch 084/200 | Loss 0.0041 | Win/lose count 6.0/1.0 (5.0)
# Epoch 085/200 | Loss 0.0075 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 086/200 | Loss 0.0176 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 087/200 | Loss 0.0078 | Win/lose count 3.5/3.0 (0.5)
# Epoch 088/200 | Loss 0.0080 | Win/lose count 6.0/4.0 (2.0)
# Epoch 089/200 | Loss 0.0001 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 090/200 | Loss 0.0059 | Win/lose count 3.5/7.0 (-3.5)
# Epoch 091/200 | Loss 0.0040 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 092/200 | Loss 0.0020 | Win/lose count 6.5/6.0 (0.5)
# Epoch 093/200 | Loss 0.0119 | Win/lose count 4.0/5.0 (-1.0)
# Epoch 094/200 | Loss 0.0069 | Win/lose count 3.0/7.0 (-4.0)
# Epoch 095/200 | Loss 0.0000 | Win/lose count 5.0/5.0 (0.0)
# Epoch 096/200 | Loss 0.0020 | Win/lose count 7.0/10.0 (-3.0)
# Epoch 097/200 | Loss 0.0119 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 098/200 | Loss 0.0137 | Win/lose count 3.0/2.0 (1.0)
# Epoch 099/200 | Loss 0.0000 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 100/200 | Loss 0.0020 | Win/lose count 3.0/3.0 (0.0)
# Epoch 101/200 | Loss 0.0156 | Win/lose count 3.0/1.0 (2.0)
# Epoch 102/200 | Loss 0.0003 | Win/lose count 1.0/5.0 (-4.0)
# Epoch 103/200 | Loss 0.0122 | Win/lose count 3.0/9.0 (-6.0)
# Epoch 104/200 | Loss 0.0083 | Win/lose count 5.0/7.0 (-2.0)
# Epoch 105/200 | Loss 0.0059 | Win/lose count 5.5/14.0 (-8.5)
# Epoch 106/200 | Loss 0.0000 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 107/200 | Loss 0.0042 | Win/lose count 2.0/0 (2.0)
# Epoch 108/200 | Loss 0.0021 | Win/lose count 0/4.0 (-4.0)
# Epoch 109/200 | Loss 0.0227 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 110/200 | Loss 0.0000 | Win/lose count 3.0/1.0 (2.0)
# Epoch 111/200 | Loss 0.0095 | Win/lose count 1.5/4.0 (-2.5)
# Epoch 112/200 | Loss 0.0020 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 113/200 | Loss 0.0080 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 114/200 | Loss 0.0076 | Win/lose count 4.5/5.0 (-0.5)
# Epoch 115/200 | Loss 0.0116 | Win/lose count 4.0/1.0 (3.0)
# Epoch 116/200 | Loss 0.0075 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 117/200 | Loss 0.0000 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 118/200 | Loss 0.0000 | Win/lose count 5.5/12.0 (-6.5)
# Epoch 119/200 | Loss 0.0293 | Win/lose count 4.0/9.0 (-5.0)
# Epoch 120/200 | Loss 0.0020 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 121/200 | Loss 0.0000 | Win/lose count 1.5/4.0 (-2.5)
# Epoch 122/200 | Loss 0.0217 | Win/lose count 4.0/8.0 (-4.0)
# Epoch 123/200 | Loss 0.0000 | Win/lose count 3.0/10.0 (-7.0)
# Epoch 124/200 | Loss 0.0096 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 125/200 | Loss 0.0121 | Win/lose count 4.0/2.0 (2.0)
# Epoch 126/200 | Loss 0.0021 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 127/200 | Loss 0.0076 | Win/lose count 1.0/4.0 (-3.0)
# Epoch 128/200 | Loss 0.0020 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 129/200 | Loss 0.0022 | Win/lose count 3.0/1.0 (2.0)
# Epoch 130/200 | Loss 0.0000 | Win/lose count 4.0/6.0 (-2.0)
# Epoch 131/200 | Loss 0.0081 | Win/lose count 2.0/6.0 (-4.0)
# Epoch 132/200 | Loss 0.0078 | Win/lose count 4.0/11.0 (-7.0)
# Epoch 133/200 | Loss 0.0110 | Win/lose count 1.5/8.0 (-6.5)
# Epoch 134/200 | Loss 0.0000 | Win/lose count 3.5/5.0 (-1.5)
# Epoch 135/200 | Loss 0.0155 | Win/lose count 1.5/1.0 (0.5)
# Epoch 136/200 | Loss 0.0175 | Win/lose count 0.5/6.0 (-5.5)
# Epoch 137/200 | Loss 0.0117 | Win/lose count 8.0/8.0 (0.0)
# Epoch 138/200 | Loss 0.0078 | Win/lose count 3.5/5.0 (-1.5)
# Epoch 139/200 | Loss 0.0118 | Win/lose count 0.5/2.0 (-1.5)
# Epoch 140/200 | Loss 0.0000 | Win/lose count 3.5/5.0 (-1.5)
# Epoch 141/200 | Loss 0.0077 | Win/lose count 4.5/7.0 (-2.5)
# Epoch 142/200 | Loss 0.0020 | Win/lose count 5.5/6.0 (-0.5)
# Epoch 143/200 | Loss 0.0214 | Win/lose count 5.5/8.0 (-2.5)
# Epoch 144/200 | Loss 0.0098 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 145/200 | Loss 0.0040 | Win/lose count 2.0/6.0 (-4.0)
# Epoch 146/200 | Loss 0.0020 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 147/200 | Loss 0.0098 | Win/lose count 5.0/12.0 (-7.0)
# Epoch 148/200 | Loss 0.0253 | Win/lose count 8.5/6.0 (2.5)
# Epoch 149/200 | Loss 0.0061 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 150/200 | Loss 0.0117 | Win/lose count 2.5/2.0 (0.5)
# Epoch 151/200 | Loss 0.0022 | Win/lose count 3.0/1.0 (2.0)
# Epoch 152/200 | Loss 0.0022 | Win/lose count 4.5/2.0 (2.5)
# Epoch 153/200 | Loss 0.0192 | Win/lose count 4.0/8.0 (-4.0)
# Epoch 154/200 | Loss 0.0326 | Win/lose count 1.0/5.0 (-4.0)
# Epoch 155/200 | Loss 0.0083 | Win/lose count 1.5/5.0 (-3.5)
# Epoch 156/200 | Loss 0.0009 | Win/lose count 1.5/6.0 (-4.5)
# Epoch 157/200 | Loss 0.0078 | Win/lose count 3.5/1.0 (2.5)
# Epoch 158/200 | Loss 0.0000 | Win/lose count 3.5/6.0 (-2.5)
# Epoch 159/200 | Loss 0.0021 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 160/200 | Loss 0.0174 | Win/lose count 2.0/7.0 (-5.0)
# Epoch 161/200 | Loss 0.0232 | Win/lose count 1.0/4.0 (-3.0)
# Epoch 162/200 | Loss 0.0075 | Win/lose count 4.5/2.0 (2.5)
# Epoch 163/200 | Loss 0.0034 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 164/200 | Loss 0.0154 | Win/lose count 3.0/5.0 (-2.0)
# Epoch 165/200 | Loss 0.0076 | Win/lose count 3.0/0 (3.0)
# Epoch 166/200 | Loss 0.0097 | Win/lose count 4.0/3.0 (1.0)
# Epoch 167/200 | Loss 0.0077 | Win/lose count 4.0/3.0 (1.0)
# Epoch 168/200 | Loss 0.0072 | Win/lose count 3.5/1.0 (2.5)
# Epoch 169/200 | Loss 0.0020 | Win/lose count 3.0/3.0 (0.0)
# Epoch 170/200 | Loss 0.0147 | Win/lose count 3.0/5.0 (-2.0)
# Epoch 171/200 | Loss 0.0074 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 172/200 | Loss 0.0000 | Win/lose count 0/6.0 (-6.0)
# Epoch 173/200 | Loss 0.0021 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 174/200 | Loss 0.0088 | Win/lose count 7.0/7.0 (0.0)
# Epoch 175/200 | Loss 0.0199 | Win/lose count 2.5/6.0 (-3.5)
# Epoch 176/200 | Loss 0.0138 | Win/lose count 3.0/3.0 (0.0)
# Epoch 177/200 | Loss 0.0020 | Win/lose count 1.5/1.0 (0.5)
# Epoch 178/200 | Loss 0.0076 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 179/200 | Loss 0.0000 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 180/200 | Loss 0.0077 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 181/200 | Loss 0.0075 | Win/lose count 3.0/5.0 (-2.0)
# Epoch 182/200 | Loss 0.0175 | Win/lose count 4.0/4.0 (0.0)
# Epoch 183/200 | Loss 0.0060 | Win/lose count 2.0/10.0 (-8.0)
# Epoch 184/200 | Loss 0.0000 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 185/200 | Loss 0.0172 | Win/lose count 5.0/6.0 (-1.0)
# Epoch 186/200 | Loss 0.0156 | Win/lose count 2.0/2.0 (0.0)
# Epoch 187/200 | Loss 0.0020 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 188/200 | Loss 0.0095 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 189/200 | Loss 0.0000 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 190/200 | Loss 0.0000 | Win/lose count 0.5/1.0 (-0.5)
# Epoch 191/200 | Loss 0.0078 | Win/lose count 1.5/1.0 (0.5)
# Epoch 192/200 | Loss 0.0000 | Win/lose count 0.5/3.0 (-2.5)
# Epoch 193/200 | Loss 0.0096 | Win/lose count 4.0/9.0 (-5.0)
# Epoch 194/200 | Loss 0.0020 | Win/lose count 1.5/1.0 (0.5)
# Epoch 195/200 | Loss 0.0078 | Win/lose count 3.0/2.0 (1.0)
# Epoch 196/200 | Loss 0.0020 | Win/lose count 1.5/1.0 (0.5)
# Epoch 197/200 | Loss 0.0000 | Win/lose count 0.5/4.0 (-3.5)
# Epoch 198/200 | Loss 0.0077 | Win/lose count 2.5/2.0 (0.5)
# Epoch 199/200 | Loss 0.0000 | Win/lose count 3.5/3.0 (0.5)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 8__ Implement the DQN training algorithm using a CNN (for example, 2 convolutional layers and one final fully connected layer).

# %%
class DQN_CNN(DQN):
    def __init__(self, *args,lr=0.1,**kwargs):
        super(DQN_CNN, self).__init__(*args,**kwargs)
        
        ###### FILL IN
        model = Sequential()
        model.add(Conv2D(32,kernel_size=(2,2),input_shape=(5,5,self.n_state), activation='relu'))
        model.add(Conv2D(32,kernel_size=(2,2),activation='relu'))
        model.add(Flatten())
        model.add(Dense(4,activation ="linear"))
        
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model
        model.summary()

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent,env,epochs_train,prefix='cnn_train')
HTML(display_videos('cnn_train10.mp4'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 4, 4, 32)          288
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 3, 3, 32)          4128
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 288)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 4)                 1156
# =================================================================
# Total params: 5,572
# Trainable params: 5,572
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/200 | Loss 0.0130 | Win/lose count 9.0/9.0 (0.0)
# Epoch 001/200 | Loss 0.0081 | Win/lose count 5.5/1.0 (4.5)
# Epoch 002/200 | Loss 0.0036 | Win/lose count 8.0/7.0 (1.0)
# Epoch 003/200 | Loss 0.0640 | Win/lose count 6.5/9.0 (-2.5)
# Epoch 004/200 | Loss 0.0056 | Win/lose count 12.5/2.0 (10.5)
# Epoch 005/200 | Loss 0.0070 | Win/lose count 4.0/1.0 (3.0)
# Epoch 006/200 | Loss 0.0065 | Win/lose count 6.0/4.0 (2.0)
# Epoch 007/200 | Loss 0.0517 | Win/lose count 14.5/2.0 (12.5)
# Epoch 008/200 | Loss 0.0045 | Win/lose count 16.5/4.0 (12.5)
# Epoch 009/200 | Loss 0.0037 | Win/lose count 9.0/2.0 (7.0)
# Epoch 010/200 | Loss 0.0063 | Win/lose count 9.0/7.0 (2.0)
# Epoch 011/200 | Loss 0.0027 | Win/lose count 7.5/6.0 (1.5)
# Epoch 012/200 | Loss 0.0043 | Win/lose count 12.0/3.0 (9.0)
# Epoch 013/200 | Loss 0.0020 | Win/lose count 7.5/5.0 (2.5)
# Epoch 014/200 | Loss 0.0033 | Win/lose count 17.5/2.0 (15.5)
# Epoch 015/200 | Loss 0.0110 | Win/lose count 8.5/2.0 (6.5)
# Epoch 016/200 | Loss 0.0010 | Win/lose count 3.5/2.0 (1.5)
# Epoch 017/200 | Loss 0.0497 | Win/lose count 10.0/2.0 (8.0)
# Epoch 018/200 | Loss 0.0043 | Win/lose count 18.5/2.0 (16.5)
# Epoch 019/200 | Loss 0.0631 | Win/lose count 5.5/3.0 (2.5)
# Epoch 020/200 | Loss 0.0030 | Win/lose count 5.0/3.0 (2.0)
# Epoch 021/200 | Loss 0.0020 | Win/lose count 13.5/4.0 (9.5)
# Epoch 022/200 | Loss 0.0018 | Win/lose count 15.5/1.0 (14.5)
# Epoch 023/200 | Loss 0.0064 | Win/lose count 7.5/3.0 (4.5)
# Epoch 024/200 | Loss 0.0029 | Win/lose count 11.5/4.0 (7.5)
# Epoch 025/200 | Loss 0.0035 | Win/lose count 9.0/1.0 (8.0)
# Epoch 026/200 | Loss 0.0100 | Win/lose count 19.5/2.0 (17.5)
# Epoch 027/200 | Loss 0.0023 | Win/lose count 15.0/3.0 (12.0)
# Epoch 028/200 | Loss 0.0044 | Win/lose count 9.5/3.0 (6.5)
# Epoch 029/200 | Loss 0.0546 | Win/lose count 10.5/3.0 (7.5)
# Epoch 030/200 | Loss 0.0046 | Win/lose count 20.0/1.0 (19.0)
# Epoch 031/200 | Loss 0.0023 | Win/lose count 15.0/1.0 (14.0)
# Epoch 032/200 | Loss 0.0027 | Win/lose count 21.0/1.0 (20.0)
# Epoch 033/200 | Loss 0.0017 | Win/lose count 19.5/5.0 (14.5)
# Epoch 034/200 | Loss 0.0013 | Win/lose count 10.5/3.0 (7.5)
# Epoch 035/200 | Loss 0.0022 | Win/lose count 22.0/7.0 (15.0)
# Epoch 036/200 | Loss 0.0048 | Win/lose count 15.0/1.0 (14.0)
# Epoch 037/200 | Loss 0.0024 | Win/lose count 16.5/4.0 (12.5)
# Epoch 038/200 | Loss 0.0029 | Win/lose count 14.5/4.0 (10.5)
# Epoch 039/200 | Loss 0.0031 | Win/lose count 14.0/5.0 (9.0)
# Epoch 040/200 | Loss 0.0026 | Win/lose count 20.5/2.0 (18.5)
# Epoch 041/200 | Loss 0.0019 | Win/lose count 19.5/1.0 (18.5)
# Epoch 042/200 | Loss 0.0019 | Win/lose count 11.5/1.0 (10.5)
# Epoch 043/200 | Loss 0.0035 | Win/lose count 8.5/2.0 (6.5)
# Epoch 044/200 | Loss 0.0056 | Win/lose count 24.5/2.0 (22.5)
# Epoch 045/200 | Loss 0.0027 | Win/lose count 23.5/2.0 (21.5)
# Epoch 046/200 | Loss 0.0027 | Win/lose count 13.0/3.0 (10.0)
# Epoch 047/200 | Loss 0.0576 | Win/lose count 19.5/1.0 (18.5)
# Epoch 048/200 | Loss 0.0026 | Win/lose count 12.5/1.0 (11.5)
# Epoch 049/200 | Loss 0.0016 | Win/lose count 14.0/4.0 (10.0)
# Epoch 050/200 | Loss 0.0017 | Win/lose count 9.0/6.0 (3.0)
# Epoch 051/200 | Loss 0.0039 | Win/lose count 14.5/5.0 (9.5)
# Epoch 052/200 | Loss 0.0032 | Win/lose count 14.0/3.0 (11.0)
# Epoch 053/200 | Loss 0.0044 | Win/lose count 20.5/3.0 (17.5)
# Epoch 054/200 | Loss 0.0015 | Win/lose count 24.0/2.0 (22.0)
# Epoch 055/200 | Loss 0.0479 | Win/lose count 7.5/2.0 (5.5)
# Epoch 056/200 | Loss 0.0072 | Win/lose count 23.0/3.0 (20.0)
# Epoch 057/200 | Loss 0.0050 | Win/lose count 13.0/3.0 (10.0)
# Epoch 058/200 | Loss 0.0030 | Win/lose count 23.5/0 (23.5)
# Epoch 059/200 | Loss 0.0023 | Win/lose count 18.0/5.0 (13.0)
# Epoch 060/200 | Loss 0.0081 | Win/lose count 13.0/4.0 (9.0)
# Epoch 061/200 | Loss 0.0019 | Win/lose count 19.5/1.0 (18.5)
# Epoch 062/200 | Loss 0.0021 | Win/lose count 20.0/10.0 (10.0)
# Epoch 063/200 | Loss 0.0022 | Win/lose count 23.0/2.0 (21.0)
# Epoch 064/200 | Loss 0.0034 | Win/lose count 13.0/5.0 (8.0)
# Epoch 065/200 | Loss 0.0527 | Win/lose count 14.0/6.0 (8.0)
# Epoch 066/200 | Loss 0.0028 | Win/lose count 21.0/4.0 (17.0)
# Epoch 067/200 | Loss 0.0030 | Win/lose count 13.0/4.0 (9.0)
# Epoch 068/200 | Loss 0.0039 | Win/lose count 6.0/1.0 (5.0)
# Epoch 069/200 | Loss 0.0573 | Win/lose count 12.0/1.0 (11.0)
# Epoch 070/200 | Loss 0.0021 | Win/lose count 6.5/6.0 (0.5)
# Epoch 071/200 | Loss 0.0027 | Win/lose count 21.5/1.0 (20.5)
# Epoch 072/200 | Loss 0.0039 | Win/lose count 8.0/0 (8.0)
# Epoch 073/200 | Loss 0.0450 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 074/200 | Loss 0.0017 | Win/lose count 7.5/2.0 (5.5)
# Epoch 075/200 | Loss 0.0026 | Win/lose count 11.5/0 (11.5)
# Epoch 076/200 | Loss 0.0013 | Win/lose count 9.0/4.0 (5.0)
# Epoch 077/200 | Loss 0.0022 | Win/lose count 14.0/8.0 (6.0)
# Epoch 078/200 | Loss 0.0480 | Win/lose count 20.0/3.0 (17.0)
# Epoch 079/200 | Loss 0.0014 | Win/lose count 13.0/2.0 (11.0)
# Epoch 080/200 | Loss 0.0020 | Win/lose count 9.0/2.0 (7.0)
# Epoch 081/200 | Loss 0.0454 | Win/lose count 10.5/4.0 (6.5)
# Epoch 082/200 | Loss 0.0101 | Win/lose count 4.0/3.0 (1.0)
# Epoch 083/200 | Loss 0.0017 | Win/lose count 11.5/1.0 (10.5)
# Epoch 084/200 | Loss 0.0514 | Win/lose count 14.5/2.0 (12.5)
# Epoch 085/200 | Loss 0.0506 | Win/lose count 13.5/1.0 (12.5)
# Epoch 086/200 | Loss 0.0079 | Win/lose count 10.5/3.0 (7.5)
# Epoch 087/200 | Loss 0.0029 | Win/lose count 13.0/2.0 (11.0)
# Epoch 088/200 | Loss 0.0040 | Win/lose count 22.5/4.0 (18.5)
# Epoch 089/200 | Loss 0.0017 | Win/lose count 14.0/0 (14.0)
# Epoch 090/200 | Loss 0.0016 | Win/lose count 13.0/2.0 (11.0)
# Epoch 091/200 | Loss 0.0024 | Win/lose count 8.5/3.0 (5.5)
# Epoch 092/200 | Loss 0.0566 | Win/lose count 16.0/3.0 (13.0)
# Epoch 093/200 | Loss 0.0015 | Win/lose count 19.5/4.0 (15.5)
# Epoch 094/200 | Loss 0.0028 | Win/lose count 9.0/0 (9.0)
# Epoch 095/200 | Loss 0.0029 | Win/lose count 22.5/5.0 (17.5)
# Epoch 096/200 | Loss 0.0041 | Win/lose count 18.5/3.0 (15.5)
# Epoch 097/200 | Loss 0.0019 | Win/lose count 21.5/1.0 (20.5)
# Epoch 098/200 | Loss 0.0042 | Win/lose count 14.5/5.0 (9.5)
# Epoch 099/200 | Loss 0.0534 | Win/lose count 18.5/1.0 (17.5)
# Epoch 100/200 | Loss 0.0023 | Win/lose count 12.0/1.0 (11.0)
# Epoch 101/200 | Loss 0.0029 | Win/lose count 14.5/2.0 (12.5)
# Epoch 102/200 | Loss 0.0027 | Win/lose count 11.5/2.0 (9.5)
# Epoch 103/200 | Loss 0.0019 | Win/lose count 6.5/3.0 (3.5)
# Epoch 104/200 | Loss 0.0624 | Win/lose count 18.5/6.0 (12.5)
# Epoch 105/200 | Loss 0.0015 | Win/lose count 13.5/0 (13.5)
# Epoch 106/200 | Loss 0.0021 | Win/lose count 19.0/0 (19.0)
# Epoch 107/200 | Loss 0.0013 | Win/lose count 13.5/5.0 (8.5)
# Epoch 108/200 | Loss 0.0021 | Win/lose count 27.0/1.0 (26.0)
# Epoch 109/200 | Loss 0.0025 | Win/lose count 5.0/5.0 (0.0)
# Epoch 110/200 | Loss 0.0020 | Win/lose count 11.0/2.0 (9.0)
# Epoch 111/200 | Loss 0.0022 | Win/lose count 16.0/3.0 (13.0)
# Epoch 112/200 | Loss 0.0076 | Win/lose count 18.0/4.0 (14.0)
# Epoch 113/200 | Loss 0.0018 | Win/lose count 17.0/7.0 (10.0)
# Epoch 114/200 | Loss 0.0044 | Win/lose count 17.0/5.0 (12.0)
# Epoch 115/200 | Loss 0.0878 | Win/lose count 22.5/1.0 (21.5)
# Epoch 116/200 | Loss 0.0024 | Win/lose count 16.5/4.0 (12.5)
# Epoch 117/200 | Loss 0.0012 | Win/lose count 9.5/4.0 (5.5)
# Epoch 118/200 | Loss 0.0012 | Win/lose count 25.0/9.0 (16.0)
# Epoch 119/200 | Loss 0.0028 | Win/lose count 24.0/2.0 (22.0)
# Epoch 120/200 | Loss 0.0059 | Win/lose count 10.0/2.0 (8.0)
# Epoch 121/200 | Loss 0.0034 | Win/lose count 15.0/3.0 (12.0)
# Epoch 122/200 | Loss 0.0023 | Win/lose count 18.0/4.0 (14.0)
# Epoch 123/200 | Loss 0.0025 | Win/lose count 23.5/4.0 (19.5)
# Epoch 124/200 | Loss 0.0017 | Win/lose count 21.5/1.0 (20.5)
# Epoch 125/200 | Loss 0.0039 | Win/lose count 10.5/3.0 (7.5)
# Epoch 126/200 | Loss 0.0038 | Win/lose count 10.0/2.0 (8.0)
# Epoch 127/200 | Loss 0.0016 | Win/lose count 13.5/2.0 (11.5)
# Epoch 128/200 | Loss 0.0079 | Win/lose count 14.5/4.0 (10.5)
# Epoch 129/200 | Loss 0.0085 | Win/lose count 14.5/6.0 (8.5)
# Epoch 130/200 | Loss 0.0024 | Win/lose count 13.0/1.0 (12.0)
# Epoch 131/200 | Loss 0.0530 | Win/lose count 20.5/4.0 (16.5)
# Epoch 132/200 | Loss 0.0538 | Win/lose count 25.0/5.0 (20.0)
# Epoch 133/200 | Loss 0.0029 | Win/lose count 19.5/2.0 (17.5)
# Epoch 134/200 | Loss 0.0026 | Win/lose count 14.5/4.0 (10.5)
# Epoch 135/200 | Loss 0.0032 | Win/lose count 15.0/3.0 (12.0)
# Epoch 136/200 | Loss 0.0037 | Win/lose count 13.0/4.0 (9.0)
# Epoch 137/200 | Loss 0.0024 | Win/lose count 19.0/3.0 (16.0)
# Epoch 138/200 | Loss 0.0484 | Win/lose count 13.5/2.0 (11.5)
# Epoch 139/200 | Loss 0.0016 | Win/lose count 25.0/1.0 (24.0)
# Epoch 140/200 | Loss 0.0510 | Win/lose count 17.0/7.0 (10.0)
# Epoch 141/200 | Loss 0.0542 | Win/lose count 19.0/8.0 (11.0)
# Epoch 142/200 | Loss 0.0017 | Win/lose count 10.5/1.0 (9.5)
# Epoch 143/200 | Loss 0.0499 | Win/lose count 18.0/2.0 (16.0)
# Epoch 144/200 | Loss 0.0016 | Win/lose count 18.5/0 (18.5)
# Epoch 145/200 | Loss 0.0021 | Win/lose count 12.5/3.0 (9.5)
# Epoch 146/200 | Loss 0.0576 | Win/lose count 21.5/0 (21.5)
# Epoch 147/200 | Loss 0.0568 | Win/lose count 19.5/3.0 (16.5)
# Epoch 148/200 | Loss 0.0109 | Win/lose count 17.5/2.0 (15.5)
# Epoch 149/200 | Loss 0.0029 | Win/lose count 14.0/4.0 (10.0)
# Epoch 150/200 | Loss 0.0078 | Win/lose count 7.0/1.0 (6.0)
# Epoch 151/200 | Loss 0.0529 | Win/lose count 18.5/5.0 (13.5)
# Epoch 152/200 | Loss 0.0030 | Win/lose count 20.5/4.0 (16.5)
# Epoch 153/200 | Loss 0.0030 | Win/lose count 12.0/2.0 (10.0)
# Epoch 154/200 | Loss 0.0015 | Win/lose count 18.5/3.0 (15.5)
# Epoch 155/200 | Loss 0.0018 | Win/lose count 21.5/3.0 (18.5)
# Epoch 156/200 | Loss 0.0016 | Win/lose count 24.0/0 (24.0)
# Epoch 157/200 | Loss 0.0015 | Win/lose count 16.0/1.0 (15.0)
# Epoch 158/200 | Loss 0.0015 | Win/lose count 24.5/2.0 (22.5)
# Epoch 159/200 | Loss 0.0029 | Win/lose count 18.0/3.0 (15.0)
# Epoch 160/200 | Loss 0.0025 | Win/lose count 17.5/2.0 (15.5)
# Epoch 161/200 | Loss 0.0033 | Win/lose count 20.0/3.0 (17.0)
# Epoch 162/200 | Loss 0.0527 | Win/lose count 8.0/2.0 (6.0)
# Epoch 163/200 | Loss 0.0539 | Win/lose count 6.0/5.0 (1.0)
# Epoch 164/200 | Loss 0.0019 | Win/lose count 11.5/3.0 (8.5)
# Epoch 165/200 | Loss 0.0059 | Win/lose count 24.0/6.0 (18.0)
# Epoch 166/200 | Loss 0.0018 | Win/lose count 21.0/3.0 (18.0)
# Epoch 167/200 | Loss 0.0020 | Win/lose count 21.5/2.0 (19.5)
# Epoch 168/200 | Loss 0.0457 | Win/lose count 5.0/1.0 (4.0)
# Epoch 169/200 | Loss 0.0047 | Win/lose count 11.5/1.0 (10.5)
# Epoch 170/200 | Loss 0.0017 | Win/lose count 24.0/3.0 (21.0)
# Epoch 171/200 | Loss 0.0018 | Win/lose count 23.0/2.0 (21.0)
# Epoch 172/200 | Loss 0.0023 | Win/lose count 9.5/3.0 (6.5)
# Epoch 173/200 | Loss 0.0039 | Win/lose count 13.5/3.0 (10.5)
# Epoch 174/200 | Loss 0.0028 | Win/lose count 21.5/1.0 (20.5)
# Epoch 175/200 | Loss 0.0024 | Win/lose count 19.5/0 (19.5)
# Epoch 176/200 | Loss 0.0494 | Win/lose count 16.5/4.0 (12.5)
# Epoch 177/200 | Loss 0.0490 | Win/lose count 14.5/5.0 (9.5)
# Epoch 178/200 | Loss 0.0153 | Win/lose count 22.5/8.0 (14.5)
# Epoch 179/200 | Loss 0.0033 | Win/lose count 10.0/2.0 (8.0)
# Epoch 180/200 | Loss 0.0024 | Win/lose count 24.0/3.0 (21.0)
# Epoch 181/200 | Loss 0.0017 | Win/lose count 10.5/6.0 (4.5)
# Epoch 182/200 | Loss 0.0023 | Win/lose count 27.5/3.0 (24.5)
# Epoch 183/200 | Loss 0.0015 | Win/lose count 22.5/3.0 (19.5)
# Epoch 184/200 | Loss 0.0021 | Win/lose count 20.5/5.0 (15.5)
# Epoch 185/200 | Loss 0.0029 | Win/lose count 11.5/2.0 (9.5)
# Epoch 186/200 | Loss 0.0021 | Win/lose count 21.0/4.0 (17.0)
# Epoch 187/200 | Loss 0.0029 | Win/lose count 10.5/2.0 (8.5)
# Epoch 188/200 | Loss 0.0054 | Win/lose count 23.5/3.0 (20.5)
# Epoch 189/200 | Loss 0.0547 | Win/lose count 20.0/4.0 (16.0)
# Epoch 190/200 | Loss 0.0013 | Win/lose count 14.5/4.0 (10.5)
# Epoch 191/200 | Loss 0.0032 | Win/lose count 17.5/4.0 (13.5)
# Epoch 192/200 | Loss 0.0030 | Win/lose count 21.5/3.0 (18.5)
# Epoch 193/200 | Loss 0.0035 | Win/lose count 13.5/6.0 (7.5)
# Epoch 194/200 | Loss 0.0020 | Win/lose count 17.0/3.0 (14.0)
# Epoch 195/200 | Loss 0.0039 | Win/lose count 20.0/4.0 (16.0)
# Epoch 196/200 | Loss 0.0018 | Win/lose count 24.5/6.0 (18.5)
# Epoch 197/200 | Loss 0.0039 | Win/lose count 8.0/0 (8.0)
# Epoch 198/200 | Loss 0.0017 | Win/lose count 17.0/4.0 (13.0)
# Epoch 199/200 | Loss 0.0444 | Win/lose count 21.5/4.0 (17.5)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 9__ Test both algorithms and compare their performances. Which issue(s) do you observe? Observe also different behaviors by changing the temperature.

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.3)
agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 4, 4, 32)          288
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 3, 3, 32)          4128
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 288)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 4)                 1156
# =================================================================
# Total params: 5,572
# Trainable params: 5,572
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_12 (Reshape)         (None, 50)                0
# _________________________________________________________________
# dense_45 (Dense)             (None, 24)                1224
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_46 (Dense)             (None, 24)                600
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_47 (Dense)             (None, 4)                 100
# =================================================================
# Total params: 1,924
# Trainable params: 1,924
# Non-trainable params: 0
# _________________________________________________________________
# Test of the CNN
# Win/lose count 1.5/1.0. Average score (0.5)
# Win/lose count 2.0/3.0. Average score (-0.25)
# Win/lose count 3.5/4.0. Average score (-0.3333333333333333)
# Win/lose count 1.0/3.0. Average score (-0.75)
# Win/lose count 0.5/4.0. Average score (-1.3)
# Win/lose count 1.5/2.0. Average score (-1.1666666666666667)
# Win/lose count 2.0/3.0. Average score (-1.1428571428571428)
# Win/lose count 1.5/3.0. Average score (-1.1875)
# Win/lose count 3.0/3.0. Average score (-1.0555555555555556)
# Win/lose count 1.5/4.0. Average score (-1.2)
# Win/lose count 2.5/2.0. Average score (-1.0454545454545454)
# Win/lose count 1.5/1.0. Average score (-0.9166666666666666)
# Win/lose count 0.5/6.0. Average score (-1.2692307692307692)
# Win/lose count 4.5/3.0. Average score (-1.0714285714285714)
# Win/lose count 2.5/2.0. Average score (-0.9666666666666667)
# Win/lose count 0.5/4.0. Average score (-1.125)
# Win/lose count 1.5/3.0. Average score (-1.1470588235294117)
# Win/lose count 1.0/2.0. Average score (-1.1388888888888888)
# Win/lose count 1.5/3.0. Average score (-1.1578947368421053)
# Win/lose count 2.5/4.0. Average score (-1.175)
# Win/lose count 4.0/3.0. Average score (-1.0714285714285714)
# Win/lose count 1.0/3.0. Average score (-1.1136363636363635)
# Win/lose count 2.0/5.0. Average score (-1.1956521739130435)
# Win/lose count 3.0/2.0. Average score (-1.1041666666666667)
# Win/lose count 1.5/1.0. Average score (-1.04)
# Win/lose count 4.5/0. Average score (-0.8269230769230769)
# Win/lose count 1.5/2.0. Average score (-0.8148148148148148)
# Win/lose count 1.5/3.0. Average score (-0.8392857142857143)
# Win/lose count 2.5/2.0. Average score (-0.7931034482758621)
# Win/lose count 2.5/4.0. Average score (-0.8166666666666667)
# Win/lose count 1.5/3.0. Average score (-0.8387096774193549)
# Win/lose count 2.0/3.0. Average score (-1.0080213903743316)
# Win/lose count 2.5/5.0. Average score (-1.0159574468085106)
# Win/lose count 4.0/3.0. Average score (-1.0052910052910053)
# Win/lose count 3.5/3.0. Average score (-0.9973684210526316)
# Win/lose count 3.5/6.0. Average score (-1.0052356020942408)
# Win/lose count 4.0/3.0. Average score (-0.9947916666666666)
# Win/lose count 3.0/3.0. Average score (-0.9896373056994818)
# Win/lose count 3.5/6.0. Average score (-0.9974226804123711)
# Win/lose count 6.0/2.0. Average score (-0.9717948717948718)
# Win/lose count 6.5/10.0. Average score (-0.9846938775510204)
# Win/lose count 2.0/3.0. Average score (-0.9847715736040609)
# Win/lose count 4.0/3.0. Average score (-0.9747474747474747)
# Win/lose count 4.0/5.0. Average score (-0.9748743718592965)
# Win/lose count 2.0/4.0. Average score (-0.98)
# Final score: -0.98

# %%
HTML(display_videos('cnn_test10.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
HTML(display_videos('fc_test10.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# # change temperatur to 0.6

# %%
# change temperature to 0.6
env = Environment(grid_size=size, max_time=T,temperature=0.6)
agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_38 (Conv2D)           (None, 4, 4, 32)          288
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 3, 3, 32)          4128
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 288)               0
# _________________________________________________________________
# dense_48 (Dense)             (None, 4)                 1156
# =================================================================
# Total params: 5,572
# Trainable params: 5,572
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_13 (Reshape)         (None, 50)                0
# _________________________________________________________________
# dense_49 (Dense)             (None, 24)                1224
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_50 (Dense)             (None, 24)                600
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_51 (Dense)             (None, 4)                 100
# =================================================================
# Total params: 1,924
# Trainable params: 1,924
# Non-trainable params: 0
# _________________________________________________________________
# Test of the CNN
# Win/lose count 4.5/5.0. Average score (-0.5)
# Win/lose count 4.5/1.0. Average score (1.5)
# Win/lose count 7.0/6.0. Average score (1.3333333333333333)
# Win/lose count 6.0/7.0. Average score (0.75)
# Win/lose count 4.5/5.0. Average score (0.5)
# Win/lose count 3.0/3.0. Average score (0.4166666666666667)
# Win/lose count 4.0/3.0. Average score (0.5)
# Win/lose count 4.5/4.0. Average score (0.5)
# Win/lose count 4.0/7.0. Average score (0.1111111111111111)
# Win/lose count 3.5/4.0. Average score (0.05)
# Win/lose count 3.0/6.0. Average score (-0.22727272727272727)
# Win/lose count 7.5/3.0. Average score (0.16666666666666666)
# Win/lose count 2.0/3.0. Average score (0.07692307692307693)
# Win/lose count 3.5/4.0. Average score (0.03571428571428571)
# Win/lose count 4.0/3.0. Average score (0.1)
# Win/lose count 4.0/4.0. Average score (0.09375)
# Win/lose count 2.5/1.0. Average score (0.17647058823529413)
# Win/lose count 6.5/2.0. Average score (0.4166666666666667)
# Win/lose count 2.5/3.0. Average score (0.3684210526315789)
# Win/lose count 6.0/3.0. Average score (0.5)
# Win/lose count 6.0/1.0. Average score (0.7142857142857143)
# Win/lose count 5.0/6.0. Average score (0.6363636363636364)
# Win/lose count 5.5/6.0. Average score (0.5869565217391305)
# Win/lose count 5.5/3.0. Average score (0.6666666666666666)
# Win/lose count 3.0/2.0. Average score (0.68)
# Win/lose count 4.5/3.0. Average score (0.7115384615384616)
# Win/lose count 6.0/4.0. Average score (0.7592592592592593)
# Win/lose count 3.5/11.0. Average score (0.4642857142857143)
# Win/lose count 5.0/8.0. Average score (0.3448275862068966)
# Win/lose count 5.5/5.0. Average score (0.35)
# Win/lose count 3.5/2.0. Average score (0.3870967741935484)
# Win/lose count 2.0/1.0. Average score (0.40625)
# Win/lose count 6.5/8.0. Average score (0.3484848484848485)
# Win/lose count 6.0/1.0. Average score (0.4852941176470588)
# Win/lose count 2.0/4.0. Average score (0.4142857142857143)
# Win/lose count 3.0/1.0. Average score (0.4583333333333333)
# Win/lose count 4.0/2.0. Average score (0.5)
# Win/lose count 4.0/4.0. Average score (0.4868421052631579)
# Win/lose count 3.0/1.0. Average score (0.5256410256410257)
# Win/lose count 5.0/7.0. Average score (0.4625)
# Win/lose count 4.5/4.0. Average score (0.4634146341463415)
# Win/lose count 7.0/2.0. Average score (0.5714285714285714)
# Win/lose count 7.0/4.0. Average score (0.627906976744186)
# Win/lose count 4.0/7.0. Average score (0.5454545454545454)
# Win/lose count 6.0/9.0. Average score (0.4666666666666667)
# Win/lose count 8.5/2.0. Average score (0.5978260869565217)
# Win/lose count 2.0/2.0. Average score (0.5851063829787234)
# Win/lose count 4.0/2.0. Average score (0.6145833333333334)
# Win/lose count 5.0/5.0. Average score (0.6020408163265306)
# Win/lose count 5.5/2.0. Average score (0.66)
# Win/lose count 4.0/3.0. Average score (0.6666666666666666)
# Win/lose count 5.5/3.0. Average score (0.7019230769230769)
# Win/lose count 4.5/7.0. Average score (0.6415094339622641)
# Win/lose count 4.0/8.0. Average score (0.5555555555555556)
# Win/lose count 3.5/3.0. Average score (0.5545454545454546)
# Win/lose count 3.5/0. Average score (0.6071428571428571)
# Win/lose count 6.0/5.0. Average score (0.6140350877192983)
# Win/lose count 10.5/1.0. Average score (0.7672413793103449)
# Win/lose count 5.5/1.0. Average score (0.8305084745762712)
# Win/lose count 6.0/4.0. Average score (0.85)
# Win/lose count 2.0/1.0. Average score (0.8524590163934426)
# Win/lose count 8.5/5.0. Average score (0.8951612903225806)
# Win/lose count 4.0/4.0. Average score (0.8809523809523809)
# Win/lose count 3.5/3.0. Average score (0.875)
# Win/lose count 6.5/3.0. Average score (0.9153846153846154)
# Win/lose count 3.5/7.0. Average score (0.8484848484848485)
# Win/lose count 4.0/2.0. Average score (0.8656716417910447)
# Win/lose count 8.0/3.0. Average score (0.9264705882352942)
# Win/lose count 3.0/5.0. Average score (0.8840579710144928)
# Win/lose count 7.0/4.0. Average score (0.9142857142857143)
# Win/lose count 6.5/4.0. Average score (0.9366197183098591)
# Win/lose count 8.5/5.0. Average score (0.9722222222222222)
# Win/lose count 7.0/3.0. Average score (1.0136986301369864)
# Win/lose count 6.5/2.0. Average score (1.0608108108108107)
# Win/lose count 3.5/1.0. Average score (1.08)
# Win/lose count 5.5/3.0. Average score (1.0986842105263157)
# Win/lose count 5.5/3.0. Average score (1.1168831168831168)
# Win/lose count 4.0/5.0. Average score (1.0897435897435896)
# Win/lose count 5.0/3.0. Average score (1.1012658227848102)
# Win/lose count 4.5/4.0. Average score (1.09375)
# Win/lose count 7.0/6.0. Average score (1.0925925925925926)
# Win/lose count 5.5/2.0. Average score (1.1219512195121952)
# Win/lose count 4.0/6.0. Average score (1.0843373493975903)
# Win/lose count 4.5/3.0. Average score (1.0892857142857142)
# Win/lose count 2.5/4.0. Average score (1.0588235294117647)
# Win/lose count 2.0/3.0. Average score (1.0348837209302326)
# Win/lose count 4.0/6.0. Average score (1.0)
# Win/lose count 6.5/5.0. Average score (1.0056818181818181)
# Win/lose count 2.0/5.0. Average score (0.9606741573033708)
# Win/lose count 7.0/3.0. Average score (0.9944444444444445)
# Win/lose count 3.5/2.0. Average score (1.0)
# Win/lose count 5.5/6.0. Average score (0.9836956521739131)
# Win/lose count 5.0/3.0. Average score (0.9946236559139785)
# Win/lose count 3.0/4.0. Average score (0.973404255319149)
# Win/lose count 3.5/2.0. Average score (0.9789473684210527)
# Win/lose count 6.0/1.0. Average score (1.0208333333333333)
# Win/lose count 2.5/1.0. Average score (1.0257731958762886)
# Win/lose count 2.0/6.0. Average score (0.9744897959183674)
# Win/lose count 3.5/3.0. Average score (0.9696969696969697)
# Win/lose count 1.5/5.0. Average score (0.925)
# Win/lose count 3.5/6.0. Average score (0.8910891089108911)
# Win/lose count 3.0/2.0. Average score (0.8921568627450981)
# Win/lose count 5.5/1.0. Average score (0.9271844660194175)
# Win/lose count 3.0/1.0. Average score (0.9375)
# Win/lose count 3.0/2.0. Average score (0.9380952380952381)
# Win/lose count 4.5/4.0. Average score (0.9339622641509434)
# Win/lose count 3.5/2.0. Average score (0.9392523364485982)
# Win/lose count 6.5/4.0. Average score (0.9537037037037037)
# Win/lose count 4.5/1.0. Average score (0.9770642201834863)
# Win/lose count 4.0/4.0. Average score (0.9681818181818181)
# Win/lose count 5.0/5.0. Average score (0.9594594594594594)
# Win/lose count 5.0/2.0. Average score (0.9776785714285714)
# Win/lose count 3.5/3.0. Average score (0.9734513274336283)
# Win/lose count 6.0/4.0. Average score (0.9824561403508771)
# Win/lose count 3.5/3.0. Average score (0.9782608695652174)
# Win/lose count 3.0/2.0. Average score (0.978448275862069)
# Win/lose count 6.5/5.0. Average score (0.9829059829059829)
# Win/lose count 3.5/3.0. Average score (0.9788135593220338)
# Win/lose count 5.5/3.0. Average score (0.9915966386554622)
# Win/lose count 4.5/2.0. Average score (1.0041666666666667)
# Win/lose count 6.0/5.0. Average score (1.0041322314049588)
# Win/lose count 5.0/5.0. Average score (0.9959016393442623)
# Win/lose count 7.5/7.0. Average score (0.991869918699187)
# Win/lose count 2.5/3.0. Average score (0.9798387096774194)
# Win/lose count 6.0/4.0. Average score (0.988)
# Win/lose count 6.0/8.0. Average score (0.9642857142857143)
# Win/lose count 2.0/1.0. Average score (0.9645669291338582)
# Win/lose count 4.5/4.0. Average score (0.9609375)
# Win/lose count 6.0/2.0. Average score (0.9844961240310077)
# Win/lose count 4.0/3.0. Average score (0.9846153846153847)
# Win/lose count 4.0/2.0. Average score (0.9923664122137404)
# Win/lose count 5.0/1.0. Average score (1.0151515151515151)
# Win/lose count 1.5/1.0. Average score (1.0112781954887218)
# Win/lose count 4.5/1.0. Average score (1.0298507462686568)
# Win/lose count 4.5/4.0. Average score (1.025925925925926)
# Win/lose count 6.0/4.0. Average score (1.0330882352941178)
# Win/lose count 4.0/5.0. Average score (1.0182481751824817)
# Win/lose count 5.5/3.0. Average score (1.0289855072463767)
# Win/lose count 5.0/4.0. Average score (1.0287769784172662)
# Win/lose count 3.0/3.0. Average score (1.0214285714285714)
# Win/lose count 4.5/7.0. Average score (0.9964539007092199)
# Win/lose count 3.0/2.0. Average score (0.9964788732394366)
# Win/lose count 5.5/8.0. Average score (0.972027972027972)
# Win/lose count 2.5/5.0. Average score (0.9479166666666666)
# Win/lose count 5.5/4.0. Average score (0.9517241379310345)
# Win/lose count 4.0/4.0. Average score (0.9452054794520548)
# Win/lose count 7.0/6.0. Average score (0.9455782312925171)
# Win/lose count 4.5/2.0. Average score (0.956081081081081)
# Win/lose count 6.0/4.0. Average score (0.9630872483221476)
# Win/lose count 4.0/3.0. Average score (0.9633333333333334)
# Win/lose count 7.0/3.0. Average score (0.9834437086092715)
# Win/lose count 4.5/5.0. Average score (0.9736842105263158)
# Win/lose count 2.5/2.0. Average score (0.9705882352941176)
# Win/lose count 2.5/0. Average score (0.9805194805194806)
# Win/lose count 4.0/4.0. Average score (0.9741935483870968)
# Win/lose count 7.0/1.0. Average score (1.0064102564102564)
# Win/lose count 5.5/4.0. Average score (1.0095541401273886)
# Win/lose count 2.5/2.0. Average score (1.0063291139240507)
# Win/lose count 5.0/3.0. Average score (1.0125786163522013)
# Win/lose count 6.0/3.0. Average score (1.025)
# Win/lose count 5.5/2.0. Average score (1.0403726708074534)
# Win/lose count 3.0/5.0. Average score (1.021604938271605)
# Win/lose count 6.5/4.0. Average score (1.030674846625767)
# Win/lose count 6.0/1.0. Average score (1.0548780487804879)
# Win/lose count 4.5/6.0. Average score (1.0393939393939393)
# Win/lose count 2.0/1.0. Average score (1.0391566265060241)
# Win/lose count 6.5/2.0. Average score (1.0598802395209581)
# Win/lose count 3.5/4.0. Average score (1.0505952380952381)
# Win/lose count 5.0/5.0. Average score (1.044378698224852)
# Win/lose count 3.0/2.0. Average score (1.0441176470588236)
# Win/lose count 4.5/6.0. Average score (1.0292397660818713)
# Win/lose count 6.0/4.0. Average score (1.0348837209302326)
# Win/lose count 3.0/5.0. Average score (1.0173410404624277)
# Win/lose count 2.5/2.0. Average score (1.014367816091954)
# Win/lose count 4.0/6.0. Average score (0.9971428571428571)
# Win/lose count 5.0/7.0. Average score (0.9801136363636364)
# Win/lose count 4.5/5.0. Average score (0.9717514124293786)
# Win/lose count 3.0/5.0. Average score (0.9550561797752809)
# Win/lose count 3.5/7.0. Average score (0.9301675977653632)
# Win/lose count 7.0/3.0. Average score (0.9472222222222222)
# Win/lose count 3.0/1.0. Average score (0.9530386740331491)
# Win/lose count 5.0/4.0. Average score (0.9532967032967034)
# Win/lose count 2.5/1.0. Average score (0.9562841530054644)
# Win/lose count 6.0/3.0. Average score (0.967391304347826)
# Win/lose count 7.0/3.0. Average score (0.9837837837837838)
# Win/lose count 3.5/8.0. Average score (0.9543010752688172)
# Win/lose count 5.0/5.0. Average score (0.9491978609625669)
# Win/lose count 4.5/1.0. Average score (0.9627659574468085)
# Win/lose count 4.5/5.0. Average score (0.955026455026455)
# Win/lose count 5.0/7.0. Average score (0.9394736842105263)
# Win/lose count 8.0/7.0. Average score (0.9397905759162304)
# Win/lose count 3.0/4.0. Average score (0.9296875)
# Win/lose count 8.0/3.0. Average score (0.9507772020725389)
# Win/lose count 2.0/4.0. Average score (0.9355670103092784)
# Win/lose count 6.5/3.0. Average score (0.9487179487179487)
# Win/lose count 2.5/4.0. Average score (0.9362244897959183)
# Win/lose count 3.0/4.0. Average score (0.9263959390862944)
# Win/lose count 6.0/1.0. Average score (0.946969696969697)
# Win/lose count 7.5/4.0. Average score (0.9597989949748744)
# Win/lose count 4.0/3.0. Average score (0.96)
# Final score: 0.96
# Test of the FC
# Win/lose count 3.5/6.0. Average score (-2.5)
# Win/lose count 4.5/5.0. Average score (-1.5)
# Win/lose count 5.5/2.0. Average score (0.16666666666666666)
# Win/lose count 5.5/3.0. Average score (0.75)
# Win/lose count 3.5/3.0. Average score (0.7)
# Win/lose count 7.0/3.0. Average score (1.25)
# Win/lose count 4.0/5.0. Average score (0.9285714285714286)
# Win/lose count 1.5/4.0. Average score (0.5)
# Win/lose count 9.0/3.0. Average score (1.1111111111111112)
# Win/lose count 2.5/3.0. Average score (0.95)
# Win/lose count 3.5/2.0. Average score (1.0)
# Win/lose count 5.0/3.0. Average score (1.0833333333333333)
# Win/lose count 10.0/4.0. Average score (1.4615384615384615)
# Win/lose count 7.0/8.0. Average score (1.2857142857142858)
# Win/lose count 7.0/5.0. Average score (1.3333333333333333)
# Win/lose count 11.5/3.0. Average score (1.78125)
# Win/lose count 6.5/8.0. Average score (1.588235294117647)
# Win/lose count 9.5/6.0. Average score (1.6944444444444444)
# Win/lose count 5.0/3.0. Average score (1.7105263157894737)
# Win/lose count 5.5/9.0. Average score (1.45)
# Win/lose count 5.5/4.0. Average score (1.4523809523809523)
# Win/lose count 5.5/4.0. Average score (1.4545454545454546)
# Win/lose count 2.5/2.0. Average score (1.4130434782608696)
# Win/lose count 7.5/4.0. Average score (1.5)
# Win/lose count 6.5/2.0. Average score (1.62)
# Win/lose count 9.5/4.0. Average score (1.7692307692307692)
# Win/lose count 9.0/5.0. Average score (1.8518518518518519)
# Win/lose count 2.5/3.0. Average score (1.7678571428571428)
# Win/lose count 4.0/10.0. Average score (1.5)
# Win/lose count 6.5/5.0. Average score (1.5)
# Win/lose count 4.0/4.0. Average score (1.4516129032258065)
# Win/lose count 4.0/6.0. Average score (1.34375)
# Win/lose count 8.0/0. Average score (1.5454545454545454)
# Win/lose count 4.5/4.0. Average score (1.5147058823529411)
# Win/lose count 7.5/8.0. Average score (1.457142857142857)
# Win/lose count 3.0/3.0. Average score (1.4166666666666667)
# Win/lose count 7.0/5.0. Average score (1.4324324324324325)
# Win/lose count 8.0/11.0. Average score (1.3157894736842106)
# Win/lose count 8.0/4.0. Average score (1.3846153846153846)
# Win/lose count 5.5/2.0. Average score (1.4375)
# Win/lose count 4.0/1.0. Average score (1.475609756097561)
# Win/lose count 7.5/9.0. Average score (1.4047619047619047)
# Win/lose count 6.5/4.0. Average score (1.430232558139535)
# Win/lose count 6.0/5.0. Average score (1.4204545454545454)
# Win/lose count 2.0/2.0. Average score (1.3888888888888888)
# Win/lose count 6.0/4.0. Average score (1.4021739130434783)
# Win/lose count 2.5/0. Average score (1.425531914893617)
# Win/lose count 1.0/4.0. Average score (1.3333333333333333)
# Win/lose count 6.0/4.0. Average score (1.346938775510204)
# Win/lose count 8.0/5.0. Average score (1.38)
# Win/lose count 12.5/6.0. Average score (1.4803921568627452)
# Win/lose count 2.0/1.0. Average score (1.4711538461538463)
# Win/lose count 6.0/3.0. Average score (1.5)
# Win/lose count 7.5/5.0. Average score (1.5185185185185186)
# Win/lose count 6.0/1.0. Average score (1.5818181818181818)
# Win/lose count 6.0/3.0. Average score (1.6071428571428572)
# Win/lose count 11.0/5.0. Average score (1.6842105263157894)
# Win/lose count 5.0/6.0. Average score (1.6379310344827587)
# Win/lose count 3.0/3.0. Average score (1.6101694915254237)
# Win/lose count 8.5/1.0. Average score (1.7083333333333333)
# Win/lose count 4.0/4.0. Average score (1.680327868852459)
# Win/lose count 6.0/2.0. Average score (1.717741935483871)
# Win/lose count 3.5/1.0. Average score (1.7301587301587302)
# Win/lose count 8.5/3.0. Average score (1.7890625)
# Win/lose count 7.5/4.0. Average score (1.8153846153846154)
# Win/lose count 10.0/7.0. Average score (1.8333333333333333)
# Win/lose count 7.0/5.0. Average score (1.835820895522388)
# Win/lose count 6.0/3.0. Average score (1.8529411764705883)
# Win/lose count 4.0/4.0. Average score (1.826086956521739)
# Win/lose count 7.0/4.0. Average score (1.8428571428571427)
# Win/lose count 9.5/3.0. Average score (1.908450704225352)
# Win/lose count 3.5/4.0. Average score (1.875)
# Win/lose count 6.5/4.0. Average score (1.8835616438356164)
# Win/lose count 5.0/4.0. Average score (1.8716216216216217)
# Win/lose count 5.5/5.0. Average score (1.8533333333333333)
# Win/lose count 7.0/3.0. Average score (1.881578947368421)
# Win/lose count 9.5/4.0. Average score (1.9285714285714286)
# Win/lose count 3.0/8.0. Average score (1.8397435897435896)
# Win/lose count 3.0/2.0. Average score (1.8291139240506329)
# Win/lose count 3.5/2.0. Average score (1.825)
# Win/lose count 5.5/8.0. Average score (1.771604938271605)
# Win/lose count 2.5/2.0. Average score (1.7560975609756098)
# Win/lose count 2.0/5.0. Average score (1.5888888888888888)
# Win/lose count 6.0/2.0. Average score (1.6066176470588236)
# Win/lose count 5.5/4.0. Average score (1.6058394160583942)
# Win/lose count 8.5/8.0. Average score (1.5978260869565217)
# Win/lose count 2.0/4.0. Average score (1.5719424460431655)
# Win/lose count 9.0/6.0. Average score (1.582142857142857)
# Win/lose count 4.5/5.0. Average score (1.5673758865248226)
# Win/lose count 6.5/9.0. Average score (1.5387323943661972)
# Win/lose count 5.5/5.0. Average score (1.5314685314685315)
# Win/lose count 7.5/6.0. Average score (1.53125)
# Win/lose count 4.0/8.0. Average score (1.493103448275862)
# Win/lose count 6.5/6.0. Average score (1.4863013698630136)
# Win/lose count 5.0/5.0. Average score (1.4761904761904763)
# Win/lose count 6.5/5.0. Average score (1.4763513513513513)
# Win/lose count 4.5/7.0. Average score (1.4496644295302012)
# Win/lose count 8.0/2.0. Average score (1.48)
# Win/lose count 4.0/4.0. Average score (1.4701986754966887)
# Win/lose count 4.5/6.0. Average score (1.450657894736842)
# Win/lose count 5.0/6.0. Average score (1.434640522875817)
# Win/lose count 8.0/7.0. Average score (1.4318181818181819)
# Win/lose count 4.5/3.0. Average score (1.4322580645161291)
# Win/lose count 5.5/2.0. Average score (1.4455128205128205)
# Win/lose count 9.5/6.0. Average score (1.4585987261146496)
# Win/lose count 4.5/4.0. Average score (1.4525316455696202)
# Win/lose count 8.5/5.0. Average score (1.4654088050314464)
# Win/lose count 5.0/4.0. Average score (1.4625)
# Win/lose count 10.0/3.0. Average score (1.4968944099378882)
# Win/lose count 7.0/5.0. Average score (1.5)
# Win/lose count 3.0/1.0. Average score (1.5030674846625767)
# Win/lose count 5.5/5.0. Average score (1.4969512195121952)
# Win/lose count 5.0/5.0. Average score (1.4878787878787878)
# Win/lose count 7.5/5.0. Average score (1.4939759036144578)
# Win/lose count 6.0/3.0. Average score (1.5029940119760479)
# Win/lose count 10.0/3.0. Average score (1.5357142857142858)
# Win/lose count 10.0/1.0. Average score (1.5798816568047338)
# Win/lose count 3.5/5.0. Average score (1.561764705882353)
# Win/lose count 5.0/1.0. Average score (1.5760233918128654)
# Win/lose count 4.0/2.0. Average score (1.5784883720930232)
# Win/lose count 3.5/0. Average score (1.5895953757225434)
# Win/lose count 5.0/4.0. Average score (1.5862068965517242)
# Win/lose count 6.0/3.0. Average score (1.5942857142857143)
# Win/lose count 2.5/4.0. Average score (1.5767045454545454)
# Win/lose count 6.0/2.0. Average score (1.5903954802259888)
# Win/lose count 11.0/7.0. Average score (1.603932584269663)
# Win/lose count 2.5/2.0. Average score (1.5977653631284916)
# Win/lose count 5.0/2.0. Average score (1.6055555555555556)
# Win/lose count 5.0/8.0. Average score (1.580110497237569)
# Win/lose count 3.5/3.0. Average score (1.5741758241758241)
# Win/lose count 6.5/3.0. Average score (1.5846994535519126)
# Win/lose count 3.0/4.0. Average score (1.5706521739130435)
# Win/lose count 7.5/4.0. Average score (1.5810810810810811)
# Win/lose count 3.5/2.0. Average score (1.5806451612903225)
# Win/lose count 6.0/6.0. Average score (1.572192513368984)
# Win/lose count 7.5/6.0. Average score (1.571808510638298)
# Win/lose count 6.5/4.0. Average score (1.5767195767195767)
# Win/lose count 10.5/3.0. Average score (1.6078947368421053)
# Win/lose count 4.0/4.0. Average score (1.5994764397905759)
# Win/lose count 6.5/1.0. Average score (1.6197916666666667)
# Win/lose count 7.0/10.0. Average score (1.5958549222797926)
# Win/lose count 9.5/8.0. Average score (1.5953608247422681)
# Win/lose count 5.0/7.0. Average score (1.5769230769230769)
# Win/lose count 2.0/2.0. Average score (1.5688775510204083)
# Win/lose count 7.5/8.0. Average score (1.5583756345177664)
# Win/lose count 9.0/9.0. Average score (1.5505050505050506)
# Win/lose count 5.5/5.0. Average score (1.5452261306532664)
# Win/lose count 5.0/3.0. Average score (1.5475)
# Final score: 1.5475

# %%
HTML(display_videos('cnn_test10.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
HTML(display_videos('fc_test10.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# The $\textbf{test}$ phrase of both fully connected layers and CNN performs poorly. The agent gets negative average scores, -0.77 for CNN and -0.98 for FC. The agent is not motivated to explore area far away from himself.
#
# By doubling the temperature to 0.6, we observe that:
#
# 1) increasing temperatur helps the agent to achieves better average scores with fully-connected layer model and CNN model. The average score is improved considerably (comparing to temperature = 0.3): 0.96 vs -0.77 for CNN and 1.55 vs -0.98 for FC
#
#
# 2) fully connected algorithm converges faster than CNN.

# %% [markdown]
# ***
#
# The algorithm tends to not explore the map which can be an issue. We propose two ideas in order to encourage exploration:
# 1. Incorporating a decreasing $\epsilon$-greedy exploration. You can use the method ```set_epsilon```
# 2. Append via the environment a new state that describes if a cell has been visited or not
#
# ***
# __Question 10__ Design a new ```train_explore``` function and environment class ```EnvironmentExploring``` to tackle the issue of exploration.

# %%
def train_explore(agent,env,epoch,prefix=''):
    pass
        
class EnvironmentExploring(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        pass
    
## use those samples of code:
#In train explore:
state, reward, game_over = env.act(action, train=True)

## In Environment exploring:
# You will have to change n_state to 3 because you will use one more layer!
reward = 0
if train:
    reward = -self.malus_position[self.x, self.y]
self.malus_position[self.x, self.y] = 0.1

reward = reward + self.board[self.x, self.y]
# 3 "feature" states instead of 2
state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

# %%
# Training
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32,n_state=3)
train_explore(agent, env, epochs_train, prefix='cnn_train_explore')
HTML(display_videos('cnn_train_explore10.mp4'))

# %%
# Evaluation
test(agent,env,epochs_test,prefix='cnn_test_explore')
HTML(display_videos('cnn_test_explore10.mp4'))

# %% [markdown]
# ***
# ***
# __BONUS question__ Use the expert DQN from the previous question to generate some winning games. Train a model that mimicks its behavior. Compare the performances.

# %% [markdown]
# ***
